# %% [markdown]
# ## GOAL
#
# Identify non-ethnic / race factors contributing to crime rate in NYC.
#
# 1. How does weather impact frequency and type of crime
# 2. How does age group influence type and intensity of crime
# 3. How does gender distribution impact type and intensity of crime
# 4. How does poverty level impact frequency and type of crime
# 5. What are clusters of demographics that can be found using arrest data alone

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
arrests = pd.read_csv('/Users/abbascauser/Documents/Data Science/Capstone/NYPD_Arrest_Data__Year_to_Date__20231017.csv')

# %%
arrests.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD              PD_DESC  KY_CD OFNS_DESC  \
# 0   263238742  02/08/2023  380.0  ROBBERY,CAR JACKING  105.0   ROBBERY
# 1   265590985  03/24/2023  155.0               RAPE 2  104.0      RAPE
# 2   265798132  03/28/2023  157.0               RAPE 1  104.0      RAPE
# 3   269233687  06/02/2023  157.0               RAPE 1  104.0      RAPE
# 4   270519574  06/28/2023  157.0               RAPE 1  104.0      RAPE
#
#      LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0  PL 1601003          F           K               62                  0
# 1  PL 1303001          F           S              120                  0
# 2  PL 1303501          F           S              120                  0
# 3  PL 1303501          F           Q              110                  0
# 4  PL 1303501          F           K               84                  0
#
#   AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# ...

# %%
arrests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112571 entries, 0 to 112570
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                112571 non-null  int64
#  1   ARREST_DATE               112571 non-null  object
#  2   PD_CD                     112110 non-null  float64
#  3   PD_DESC                   112571 non-null  object
#  4   KY_CD                     112105 non-null  float64
#  5   OFNS_DESC                 112571 non-null  object
#  6   LAW_CODE                  112571 non-null  object
#  7   LAW_CAT_CD                111725 non-null  object
#  8   ARREST_BORO               112571 non-null  object
#  9   ARREST_PRECINCT           112571 non-null  int64
#  10  JURISDICTION_CODE         112571 non-null  int64
#  11  AGE_GROUP                 112571 non-null  object
#  12  PERP_SEX                  112571 non-null  object
# ...

# %%
financial = pd.read_csv('/Users/abbascauser/Documents/Data Science/Capstone/Neighborhood_Financial_Health_Digital_Mapping_and_Data_Tool_20231017.csv')

# %%
financial.head()
# Out:
#    Year Published  PUMA Borough                       Neighborhoods  \
# 0            2020  3701   Bronx  Riverdale, Fieldston & Kingsbridge
# 1            2020  3701   Bronx  Riverdale, Fieldston & Kingsbridge
# 2            2020  3701   Bronx  Riverdale, Fieldston & Kingsbridge
# 3            2020  3701   Bronx  Riverdale, Fieldston & Kingsbridge
# 4            2020  3701   Bronx  Riverdale, Fieldston & Kingsbridge
#
#                         CD  Join  NYC_Poverty_Rate  Median_Income  Perc_White  \
# 0  BX Community District 8  3701             0.152          30437       0.324
# 1  BX Community District 8  3701             0.152          30437       0.324
# 2  BX Community District 8  3701             0.152          30437       0.324
# 3  BX Community District 8  3701             0.152          30437       0.324
# 4  BX Community District 8  3701             0.152          30437       0.324
#
#    Perc_Black  ...  Ind6Rank  \
# 0       0.124  ...      32.0
# ...

# %%
demo_stats = pd.read_csv('/Users/abbascauser/Documents/Data Science/Capstone/Demographic_Statistics_By_Zip_Code_20231017.csv')

# %%
demo_stats.head()
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0              10001                  44            22            0.50
# 1              10002                  35            19            0.54
# 2              10003                   1             1            1.00
# 3              10004                   0             0            0.00
# 4              10005                   2             2            1.00
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 0          22          0.50                     0                       0
# 1          16          0.46                     0                       0
# 2           0          0.00                     0                       0
# 3           0          0.00                     0                       0
# 4           0          0.00                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# ...

# %%
demo_snap = pd.read_csv('/Users/abbascauser/Documents/Data Science/Capstone/2017-18__-_2021-22_Demographic_Snapshot_20231017.csv')

# %%
demo_snap
# Out:
#          DBN                        School Name     Year  Total Enrollment  \
# 0     01M015          P.S. 015 Roberto Clemente  2017-18               190
# 1     01M015          P.S. 015 Roberto Clemente  2018-19               174
# 2     01M015          P.S. 015 Roberto Clemente  2019-20               190
# 3     01M015          P.S. 015 Roberto Clemente  2020-21               193
# 4     01M015          P.S. 015 Roberto Clemente  2021-22               179
# ...      ...                                ...      ...               ...
# 9246  84X730  Bronx Charter School for the Arts  2017-18               314
# 9247  84X730  Bronx Charter School for the Arts  2018-19               430
# 9248  84X730  Bronx Charter School for the Arts  2019-20               523
# 9249  84X730  Bronx Charter School for the Arts  2020-21               626
# 9250  84X730  Bronx Charter School for the Arts  2021-22               598
#
# ...

# %%
demo_snap['% White'].mean()
# Out:
# 0.11862641876553887

# %% [markdown]
# #### To Dos
#
# 1. Join arrests lon lat with
